# %% [markdown]
# <a href="https://colab.research.google.com/github/alifele/Sklearn/blob/master/PolynomialRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 10*np.random.random((100,1))
y = 2 + 3*x + 5*x**2 +50* np.random.random((100,1))
plt.scatter(x,y)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=True)
X = poly_features.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
y_pred = model.predict(X)
plt.scatter(x,y_pred)
plt.scatter(x,y,c='red',alpha=0.4)
